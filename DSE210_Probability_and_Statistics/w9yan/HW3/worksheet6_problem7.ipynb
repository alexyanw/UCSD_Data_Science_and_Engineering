# %%
### Worksheet6 - problem 7
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.mlab import bivariate_normal
x = np.arange(-3.0, 3.0, 0.1)
y = np.arange(-3.0, 3.0, 0.1)
X, Y = np.meshgrid(x, y)
Z = bivariate_normal(X, Y, 3, 1, 0.0, 0.0, 0.0)
plt.contour(X,Y,Z)
plt.show()
Z = bivariate_normal(X, Y, sigmax=1.0, sigmay=1.0, mux=0.0, muy=0.0, sigmaxy=-0.75)
plt.contour(X,Y,Z)
plt.show()
